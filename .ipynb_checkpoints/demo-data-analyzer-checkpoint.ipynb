# %% [markdown]
# Link to my remote repo `https://github.com/Adedols/demographic-data-analyzer.git`
#
#
#
# working directory `C:\\Users\\Matri\\Desktop\\jupyter notebook\\demographic-data-analyzer-project`

# %%
import pandas as pd

# %%
df = pd.read_csv('adult_data.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
race_count = df['race'].value_counts()
race_count
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
gender_group = df.groupby('sex')[['age']].mean()
gender_group
# Out:
#               age
# sex
# Female  36.858230
# Male    39.433547

# %%
average_age_men = df.groupby('sex')[['age']].mean().loc['Male']
average_age_men
# Out:
# age    39.433547
# Name: Male, dtype: float64

# %%
(df['education'].value_counts()/df['education'].count())*100
# Out:
# education
# HS-grad         32.250238
# Some-college    22.391818
# Bachelors       16.446055
# Masters          5.291607
# Assoc-voc        4.244341
# 11th             3.608612
# Assoc-acdm       3.276926
# 10th             2.865391
# 7th-8th          1.983969
# Prof-school      1.768987
# 9th              1.578576
# 12th             1.329812
# Doctorate        1.268389
# 5th-6th          1.022696
# 1st-4th          0.515955
# Preschool        0.156629
# Name: count, dtype: float64

# %%
advanced_education = ['Masters', 'Bachelors', 'Doctorate']

# %%
higher_education = df[df['education'].isin(advanced_education)]
higher_education_rich = (higher_education[higher_education['salary'] == '>50K'].shape[0] / higher_education.shape[0]) * 100

# Calculate the percentage of people without advanced education making more than 50K
lower_education = df[~df['education'].isin(advanced_education)]
lower_education_rich = (lower_education[lower_education['salary'] == '>50K'].shape[0] / lower_education.shape[0]) * 100

# %%
higher_education
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
higher_education_rich
# Out:
# 46.535843011613935

# %%
ed_sal = df.groupby('salary')
ed_sal

# %%
ed_sal_group= ed_sal[['education']].value_counts()
ed_sal_group
# Out:
# salary  education
# <=50K   HS-grad         8826
#         Some-college    5904
#         Bachelors       3134
#         11th            1115
#         Assoc-voc       1021
#         10th             871
#         Assoc-acdm       802
#         Masters          764
#         7th-8th          606
#         9th              487
#         12th             400
#         5th-6th          317
#         1st-4th          162
#         Prof-school      153
#         Doctorate        107
#         Preschool         51
# >50K    Bachelors       2221
#         HS-grad         1675
#         Some-college    1387
#         Masters          959
#         Prof-school      423
#         Assoc-voc        361
#         Doctorate        306
#         Assoc-acdm       265
#         10th              62
#         11th              60
#         7th-8th           40
#         12th              33
#         9th               27
#         5th-6th           16
#         1st-4th            6
# ...

# %%
ed_sal_count = ed_sal[['education']].count()
ed_sal_count
# Out:
#         education
# salary
# <=50K       24720
# >50K         7841

# %%
percentage_bachelors = ((df['education'].value_counts()/df['education'].count())*100).loc['Bachelors']
percentage_bachelors
# Out:
# 16.44605509658794

# %%
df.salary.unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df['hours-per-week'].unique()
# Out:
# array([40, 13, 16, 45, 50, 80, 30, 35, 60, 20, 52, 44, 15, 25, 38, 43, 55,
#        48, 58, 32, 70,  2, 22, 56, 41, 28, 36, 24, 46, 42, 12, 65,  1, 10,
#        34, 75, 98, 33, 54,  8,  6, 64, 19, 18, 72,  5,  9, 47, 37, 21, 26,
#        14,  4, 59,  7, 99, 53, 39, 62, 57, 78, 90, 66, 11, 49, 84,  3, 17,
#        68, 27, 85, 31, 51, 77, 63, 23, 87, 88, 73, 89, 97, 94, 29, 96, 67,
#        82, 86, 91, 81, 76, 92, 61, 74, 95], dtype=int64)

# %%
df.drop(df[df['hours-per-week'] < 10].index, inplace = True)

# %%
df['hours-per-week'].describe()
# Out:
# count    32103.000000
# mean        40.933215
# std         11.708405
# min         10.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
min_work_hours = df['hours-per-week'].describe().loc['min']

# %%
min_work_hours
# Out:
# 10.0

# %%
week_sal= df.groupby('hours-per-week')[['salary']].value_counts()

# %%
week_sal
# Out:
# hours-per-week  salary
# 10              <=50K     258
#                 >50K       20
# 11              <=50K      11
# 12              <=50K     161
#                 >50K       12
#                          ...
# 97              >50K        1
# 98              <=50K       8
#                 >50K        3
# 99              <=50K      60
#                 >50K       25
# Name: count, Length: 155, dtype: int64

# %%
 week_sal = df[['hours-per-week', 'salary']]

# %%
week_sal[week_sal['hours-per-week'] == 10][['salary'] == '>50K'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ...

# %%
min_hours_per_week= df['hours-per-week'].min()
min_hours_per_week
# Out:
# 10

# %%
df[df['hours-per-week'] == min_hours_per_week]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 226     60                 ?   24215          10th              6
# 324     76  Self-emp-not-inc  174309       Masters             14
# 371     17           Private   89821          11th              7
# 375     20         Local-gov  350845  Some-college             10
# 672     17  Self-emp-not-inc  368700          11th              7
# ...    ...               ...     ...           ...            ...
# 32115   29           Private  119359       HS-grad              9
# 32153   65           Private  174603       5th-6th              3
# 32244   58  Self-emp-not-inc   99141       HS-grad              9
# 32284   26           Private  164488     Bachelors             13
# 32539   71                 ?  287372     Doctorate             16
#
#            marital-status         occupation   relationship  \
# 226              Divorced                  ?  Not-in-family
# ...

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 28755
# Mexico                          637
# ?                               576
# Philippines                     196
# Germany                         135
# Canada                          119
# Puerto-Rico                     112
# El-Salvador                     104
# India                            99
# Cuba                             93
# England                          88
# Jamaica                          81
# South                            78
# China                            74
# Italy                            71
# Dominican-Republic               70
# Vietnam                          64
# Guatemala                        64
# Japan                            62
# Poland                           59
# Columbia                         58
# Taiwan                           50
# Haiti                            44
# Iran                             42
# Portugal                         37
# ...

# %%
df[df['salary'] == '>50K']['native-country'].value_counts()
# Out:
# native-country
# United-States         7129
# ?                      145
# Philippines             61
# Germany                 43
# India                   40
# Canada                  39
# Mexico                  33
# England                 30
# Italy                   25
# Cuba                    25
# Japan                   24
# Taiwan                  20
# China                   20
# Iran                    18
# South                   16
# Poland                  12
# France                  12
# Puerto-Rico             11
# Jamaica                 10
# El-Salvador              9
# Greece                   8
# Cambodia                 7
# Yugoslavia               6
# Hong                     6
# Ireland                  5
# Vietnam                  5
# Portugal                 4
# Haiti                    4
# Ecuador                  4
# Scotland                 3
# Guatemala                3
# Thailand                 3
# Hungary                  3
# ...

# %%
(df[df['salary'] == '>50K']['native-country'].value_counts() / df['native-country'].value_counts() * 100).max()
# Out:
# 42.857142857142854

# %%
(df[df['salary'] == '>50K']['native-country'].value_counts() / df['native-country'].value_counts() * 100).idxmax()
# Out:
# 'Iran'

# %%
india_high_earners = df[(df['native-country'] == 'India') & (df['salary'] == '>50K')]
india_high_earners
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 11      30         State-gov  141297    Bachelors             13
# 968     48           Private  164966    Bachelors             13
# 1327    52           Private  168381      HS-grad              9
# 7258    42         State-gov  102343  Prof-school             15
# 7285    54         State-gov   93449      Masters             14
# 8124    36           Private  172104  Prof-school             15
# 9939    43       Federal-gov  325706  Prof-school             15
# 10590   35           Private   98283  Prof-school             15
# 10661   59           Private  122283  Prof-school             15
# 10736   30           Private  243190  Prof-school             15
# 11260   54           Private  225599      Masters             14
# 11384   34           Private   98283  Prof-school             15
# 13422   53           Private  366957    Bachelors             13
# ...

# %%
india_high_earners['occupation'].value_counts().idxmax()
# Out:
# 'Prof-specialty'

# %%
 # with and without `Bachelors`, `Masters`, or `Doctorate`
higher_education = df[df['education'].isin(advanced_education)]
lower_education = df[~df['education'].isin(advanced_education)]

# %%
higher_education
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
lower_education
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 10      37           Private  280464  Some-college             10
# ...    ...               ...     ...           ...            ...
# 32556   27           Private  257302    Assoc-acdm             12
# 32557   40           Private  154374       HS-grad              9
# 32558   58           Private  151910       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation   relationship   race     sex  \
# 2                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
 # percentage with salary >50K
higher_education_rich = (higher_education[higher_education['salary'] == '>50K'].shape[0] / higher_education.shape[0]) * 100    
lower_education_rich = (lower_education[lower_education['salary'] == '>50K'].shape[0] / lower_education.shape[0]) * 100

# %%
higher_education_rich
# Out:
# 46.76132521974307

# %%
lower_education_rich
# Out:
# 17.557066537153958

# %%
higher_education[higher_education['salary'] == '>50K'].shape[0]
# Out:
# 3458

# %%
higher_education.shape[0]
# Out:
# 7395
